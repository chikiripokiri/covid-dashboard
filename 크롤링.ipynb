# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint

html=requests.get("https://search.naver.com/search.naver?where=nexearch&sm=top_sly.hst&fbm=0&acr=3&ie=utf8&query=%EB%82%A0%EC%94%A8&ackey=jiu5cbj0")
soup=bs(html.text,'html.parser')
data1=soup.find('span', {'class':'box'})
pprint(data1)
